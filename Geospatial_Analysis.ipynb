# %%
from geopandas import gpd

# %%
full_data = gpd.read_file("data/DEC_lands/DEC_lands.shp")

# %%
full_data.head(2)
# Out:
#    OBJECTID          CATEGORY UNIT                    FACILITY        CLASS  \
# 0         1  FOR PRES DET PAR  CFP  HANCOCK FP DETACHED PARCEL  WILD FOREST
# 1         2  FOR PRES DET PAR  CFP  HANCOCK FP DETACHED PARCEL  WILD FOREST
#
#    UMP                       DESCRIPTIO  REGION    COUNTY  \
# 0  NaN  DELAWARE COUNTY DETACHED PARCEL       4  DELAWARE
# 1  NaN  DELAWARE COUNTY DETACHED PARCEL       4  DELAWARE
#
#                       URL        SOURCE UPDATE_    OFFICE       ACRES  \
# 0  http://www.dec.ny.gov/  DELAWARE RPP    5/12  STAMFORD  738.620192
# 1  http://www.dec.ny.gov/  DELAWARE RPP    5/12  STAMFORD  282.553140
#
#    LANDS_UID GREENCERT    SHAPE_AREA    SHAPE_LEN  \
# 0        103         N  2.990365e+06  7927.662385
# 1       1218         N  1.143940e+06  4776.375600
#
#                                             geometry
# 0  POLYGON ((486093.245 4635308.586, 486787.235 4...
# 1  POLYGON ((491931.514 4637416.256, 491305.424 4...

# %%
full_data.shape
# Out:
# (2983, 19)

# %%
data = full_data.loc[:, ['CLASS','COUNTY','geometry']]

# %%
data.value_counts(data['CLASS'])
# Out:
# CLASS
# WILD FOREST                   965
# INTENSIVE USE                 108
# PRIMITIVE                      60
# WILDERNESS                     52
# ADMINISTRATIVE                 17
# UNCLASSIFIED                    7
# HISTORIC                        5
# PRIMITIVE BICYCLE CORRIDOR      4
# CANOE AREA                      1
# dtype: int64

# %%
# Select lands that fall under the "WILD FOREST" or "WILDERNESS" category
wild_lands = data.loc[data['CLASS'].isin(['WILD FOREST', 'WILDERNESS'])]

# %%
wild_lands.head()
# Out:
#          CLASS    COUNTY                                           geometry
# 0  WILD FOREST  DELAWARE  POLYGON ((486093.245 4635308.586, 486787.235 4...
# 1  WILD FOREST  DELAWARE  POLYGON ((491931.514 4637416.256, 491305.424 4...
# 2  WILD FOREST  DELAWARE  POLYGON ((486000.287 4635834.453, 485007.550 4...
# 3  WILD FOREST    GREENE  POLYGON ((541716.775 4675243.268, 541217.579 4...
# 4  WILD FOREST     ESSEX  POLYGON ((583896.043 4909643.187, 583891.200 4...

# %%
wild_lands.plot()
# Out:
# <AxesSubplot:>

# %%
wild_lands.geometry.head()
# Out:
# 0    POLYGON ((486093.245 4635308.586, 486787.235 4...
# 1    POLYGON ((491931.514 4637416.256, 491305.424 4...
# 2    POLYGON ((486000.287 4635834.453, 485007.550 4...
# 3    POLYGON ((541716.775 4675243.268, 541217.579 4...
# 4    POLYGON ((583896.043 4909643.187, 583891.200 4...
# Name: geometry, dtype: geometry

# %%
# Campsites in New York state (Point)
#POI_data = gpd.read_file("data/Decptsofinterest.shp")
#campsites = POI_data.loc[POI_data.ASSET=='PRIMITIVE CAMPSITE'].copy()

# Foot trails in New York state (LineString)
roads_trails = gpd.read_file("data/DEC_roadstrails/Decroadstrails.shp")
trails = roads_trails.loc[roads_trails.ASSET=='FOOT TRAIL'].copy()

# County boundaries in New York state (Polygon)
counties = gpd.read_file("data/NY_county_boundaries/NY_county_boundaries.shp")

# %%
# Define a base map with county boundaries
ax = counties.plot(figsize=(10,10), color='none', edgecolor='gainsboro', zorder=3)

# Add wild lands, campsites, and foot trails to the base map
wild_lands.plot(color='lightgreen', ax=ax)
#campsites.plot(color='maroon', markersize=2, ax=ax)
trails.plot(color='black', markersize=1, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercise: Your First Map

# %%
from geopandas import gpd

kiva_loans = gpd.read_file('data/kiva_loans/kiva_loans.shp')

# %%
kiva_loans.head()
# Out:
#    Partner ID                       Field Part                       sector  \
# 0           9  KREDIT Microfinance Institution  General Financial Inclusion
# 1           9  KREDIT Microfinance Institution  General Financial Inclusion
# 2           9  KREDIT Microfinance Institution  General Financial Inclusion
# 3           9  KREDIT Microfinance Institution  General Financial Inclusion
# 4           9  KREDIT Microfinance Institution  General Financial Inclusion
#
#                Loan Theme   country  amount                    geometry
# 0        Higher Education  Cambodia     450  POINT (102.89751 13.66726)
# 1  Vulnerable Populations  Cambodia   20275  POINT (102.98962 13.02870)
# 2        Higher Education  Cambodia    9150  POINT (102.98962 13.02870)
# 3  Vulnerable Populations  Cambodia  604950  POINT (105.31312 12.09829)
# 4              Sanitation  Cambodia     275  POINT (105.31312 12.09829)

# %%
kiva_loans.plot(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
world_filepath = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file(world_filepath)
# Out:
# <ipython-input-28-884035ac4723>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_filepath = gpd.datasets.get_path('naturalearth_lowres')

# %%
world.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.plot()
# Out:
# <AxesSubplot:>

# %%
ax = world.plot(figsize=(20,20), color='whitesmoke', linestyle='-', edgecolor='black')
kiva_loans.plot(ax=ax, markersize=2)
# Out:
# <AxesSubplot:>

# %%
PHL_loans = kiva_loans.loc[kiva_loans['country'] == 'Philippines'].copy()

# %%
PHL_loans.head(2)
# Out:
#       Partner ID                  Field Part                       sector  \
# 2859         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
# 2860         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
#
#      Loan Theme      country  amount                    geometry
# 2859    General  Philippines     400  POINT (121.73961 17.64228)
# 2860    General  Philippines     400  POINT (121.74169 17.63235)

# %%
# Load a KML file containing island boundaries
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
PHL = gpd.read_file("data/Philippines_AL258.kml", driver='KML')
PHL.head()
# Out:
#                                    Name Description  \
# 0  Autonomous Region in Muslim Mindanao
# 1                          Bicol Region
# 2                        Cagayan Valley
# 3                            Calabarzon
# 4                                Caraga
#
#                                             geometry
# 0  MULTIPOLYGON (((119.46690 4.58718, 119.46653 4...
# 1  MULTIPOLYGON (((124.04577 11.57862, 124.04594 ...
# 2  MULTIPOLYGON (((122.51581 17.04436, 122.51568 ...
# 3  MULTIPOLYGON (((120.49202 14.05403, 120.49201 ...
# 4  MULTIPOLYGON (((126.45401 8.24400, 126.45407 8...

# %%
PHL.plot()
# Out:
# <AxesSubplot:>

# %%
ax = PHL.plot(figsize=(20,20), color='whitesmoke', linestyle='-', edgecolor='black')
PHL_loans.plot(ax=ax, markersize=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Coordinate Reference Systems

# %%
from geopandas import gpd
import pandas as pd

# %%
regions = gpd.read_file("data/ghana/Regions/Map_of_Regions_in_Ghana.shp")
print(regions.crs)
# Out:
# EPSG:32630

# %%
regions.plot()
# Out:
# <AxesSubplot:>

# %%
# Health facilities in Ghana
facilities_df = pd.read_csv("data/ghana/health_facilities.csv")

# Convert the DataFrame to a GeoDataFrame
facilities = gpd.GeoDataFrame(facilities_df, geometry=gpd.points_from_xy(facilities_df.Longitude, facilities_df.Latitude))

# Set the coordinate reference system (CRS) to EPSG 4326
facilities.crs = {'init': 'epsg:4326'}

# View the first five rows of the GeoDataFrame
facilities.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#     Region          District             FacilityName           Type  \
# 0  Ashanti     Offinso North        A.M.E Zion Clinic         Clinic
# 1  Ashanti  Bekwai Municipal        Abenkyiman Clinic         Clinic
# 2  Ashanti      Adansi North     Aboabo Health Centre  Health Centre
# 3  Ashanti     Afigya-Kwabre  Aboabogya Health Centre  Health Centre
# 4  Ashanti            Kwabre     Aboaso Health Centre  Health Centre
#
#            Town   Ownership  Latitude  Longitude                  geometry
# 0      Afrancho        CHAG   7.40801   -1.96317  POINT (-1.96317 7.40801)
# ...

# %%
facilities_df.head(2)
# Out:
#     Region          District       FacilityName    Type          Town  \
# 0  Ashanti     Offinso North  A.M.E Zion Clinic  Clinic      Afrancho
# 1  Ashanti  Bekwai Municipal  Abenkyiman Clinic  Clinic  Anwiankwanta
#
#   Ownership  Latitude  Longitude
# 0      CHAG   7.40801   -1.96317
# 1   Private   6.46312   -1.58592

# %%
ax = regions.plot(figsize=(20,20), color='whitesmoke', linestyle='-', edgecolor='black')
facilities.to_crs(epsg=32630).plot(ax=ax, markersize=2)
# Out:
# <AxesSubplot:>

# %%
# Get the x-coordinate of each point
facilities.geometry.head().x
# Out:
# 0   -1.96317
# 1   -1.58592
# 2   -1.34982
# 3   -1.61098
# 4   -1.61098
# dtype: float64

# %%
regions.head()
# Out:
#           Region                                           geometry
# 0        Ashanti  POLYGON ((686446.075 842986.894, 686666.193 84...
# 1    Brong Ahafo  POLYGON ((549970.457 968447.094, 550073.003 96...
# 2        Central  POLYGON ((603176.584 695877.238, 603248.424 69...
# 3        Eastern  POLYGON ((807307.254 797910.553, 807311.908 79...
# 4  Greater Accra  POLYGON ((858081.638 676424.913, 858113.115 67...

# %%
regions["AREA"] = regions.geometry.area / 10**6

# %%
regions.head(2)
# Out:
#         Region                                           geometry  \
# 0      Ashanti  POLYGON ((686446.075 842986.894, 686666.193 84...
# 1  Brong Ahafo  POLYGON ((549970.457 968447.094, 550073.003 96...
#
#            AREA
# 0  24379.017777
# 1  40098.168231

# %%
print(f'region of Ghana = {regions["AREA"].sum()}')
# Out:
# region of Ghana = 239584.5760055668

# %%
print("CRS:", regions.crs)
# Out:
# CRS: EPSG:32630

# %% [markdown]
# ## Exercise: Coordinate Reference Systems

# %%
import pandas as pd
import geopandas as gpd

from shapely.geometry import LineString

# %%
purple_martin = pd.read_csv('data/purple_martin.csv',  parse_dates=['timestamp'])

# %%
purple_martin.head()
# Out:
#             timestamp  location-long  location-lat  tag-local-identifier
# 0 2014-08-15 05:56:00     -88.146014     17.513049                 30448
# 1 2014-09-01 05:59:00     -85.243501     13.095782                 30448
# 2 2014-10-30 23:58:00     -62.906089     -7.852436                 30448
# 3 2014-11-15 04:59:00     -61.776826    -11.723898                 30448
# 4 2014-11-30 09:59:00     -61.241538    -11.612237                 30448

# %%
purple_martin['tag-local-identifier'].unique()
# Out:
# array([30448, 30445, 30384, 30380, 30304, 30198, 30048, 30300, 30054,
#        30275, 30263])

# %%
birds = gpd.GeoDataFrame(data = purple_martin, 
                         geometry=gpd.points_from_xy(purple_martin['location-long'], purple_martin['location-lat']))

# %%
birds.head()
# Out:
#             timestamp  location-long  location-lat  tag-local-identifier  \
# 0 2014-08-15 05:56:00     -88.146014     17.513049                 30448
# 1 2014-09-01 05:59:00     -85.243501     13.095782                 30448
# 2 2014-10-30 23:58:00     -62.906089     -7.852436                 30448
# 3 2014-11-15 04:59:00     -61.776826    -11.723898                 30448
# 4 2014-11-30 09:59:00     -61.241538    -11.612237                 30448
#
#                       geometry
# 0   POINT (-88.14601 17.51305)
# 1   POINT (-85.24350 13.09578)
# 2   POINT (-62.90609 -7.85244)
# 3  POINT (-61.77683 -11.72390)
# 4  POINT (-61.24154 -11.61224)

# %%
birds.crs = {'init' :'epsg:4326'}
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
americas = world.loc[world['continent'].isin(['North America', 'South America'])]
americas.head()
# Out:
# <ipython-input-83-4615ffccd674>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#         pop_est      continent                      name iso_a3  gdp_md_est  \
# 3    37589262.0  North America                    Canada    CAN     1736425
# 4   328239523.0  North America  United States of America    USA    21433226
# 9    44938712.0  South America                 Argentina    ARG      445445
# 10   18952038.0  South America                     Chile    CHL      282318
# 16   11263077.0  North America                     Haiti    HTI       14332
#
#                                              geometry
# 3   MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4   MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ...

# %%
ax = americas.plot(figsize=(10,10), color='whitesmoke', linestyle='-', edgecolor='black')
birds.to_crs(epsg=4326).plot(ax=ax, markersize=2)
# Out:
# <AxesSubplot:>

# %%
birds.shape
# Out:
# (99, 5)

# %%
path_df = birds.groupby('tag-local-identifier')['geometry'].apply(lambda x: LineString(x)).reset_index()

# %%
path_df.head()
# Out:
#    tag-local-identifier                                           geometry
# 0                 30048  LINESTRING (-90.12992 20.73242, -56.29394 -10....
# 1                 30054  LINESTRING (-93.60861 46.50563, -63.28897 -5.7...
# 2                 30198  LINESTRING (-80.31036 25.92545, -88.14608 17.5...
# 3                 30263  LINESTRING (-76.78146 42.99209, -62.90648 -7.8...
# 4                 30275  LINESTRING (-76.78213 42.99207, -60.26131 -15....

# %%
path_gdf = gpd.GeoDataFrame(data = path_df)

# %%
path_gdf.head()
# Out:
#    tag-local-identifier                                           geometry
# 0                 30048  LINESTRING (-90.12992 20.73242, -56.29394 -10....
# 1                 30054  LINESTRING (-93.60861 46.50563, -63.28897 -5.7...
# 2                 30198  LINESTRING (-80.31036 25.92545, -88.14608 17.5...
# 3                 30263  LINESTRING (-76.78146 42.99209, -62.90648 -7.8...
# 4                 30275  LINESTRING (-76.78213 42.99207, -60.26131 -15....

# %%
path_gdf.crs = {'init' :'epsg:4326'}
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
start_path_df = birds.groupby('tag-local-identifier')['geometry'].first().reset_index()

# %%
start_path_df.head()
# Out:
#    tag-local-identifier                    geometry
# 0                 30048  POINT (-90.12992 20.73242)
# 1                 30054  POINT (-93.60861 46.50563)
# 2                 30198  POINT (-80.31036 25.92545)
# 3                 30263  POINT (-76.78146 42.99209)
# 4                 30275  POINT (-76.78213 42.99207)

# %%
start_gdf = gpd.GeoDataFrame(data = start_path_df)

# %%
start_gdf.crs = {'init' :'epsg:4326'}

# %%
end_path_df = birds.groupby('tag-local-identifier')['geometry'].last().reset_index()

# %%
end_gdf = gpd.GeoDataFrame(data = end_path_df)

# %%
end_gdf.crs = {'init' :'epsg:4326'}
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
ax = americas.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='gray')

start_gdf.plot(ax=ax, color='red',  markersize=30)
path_gdf.plot(ax=ax, cmap='tab20b', linestyle='-', linewidth=1, zorder=1)
end_gdf.plot(ax=ax, color='black', markersize=30)
# Out:
# <AxesSubplot:>

# %%
protected_filepath = "data/SAPA_Aug2019-shapefile/SAPA_Aug2019-shapefile-polygons.shp"
protected_areas = gpd.read_file(protected_filepath)

# %%
protected_areas.head()
# Out:
#         WDPAID   WDPA_PID PA_DEF                        NAME  \
# 0      14067.0      14067      1           Het Spaans Lagoen
# 1      14003.0      14003      1  Bubali Pond Bird Sanctuary
# 2  555624439.0  555624439      1        Arikok National Park
# 3     303894.0     303894      1                      Madidi
# 4     303893.0     303893      1                  Apolobamba
#
#                     ORIG_NAME  \
# 0           Het Spaans Lagoen
# 1  Bubali Pond Bird Sanctuary
# 2        Arikok National Park
# 3                      Madidi
# 4                  Apolobamba
#
#                                               DESIG  \
# 0  Ramsar Site, Wetland of International Importance
# 1                                    Bird Sanctuary
# 2                                     National Park
# 3                  Area Natural de Manejo Integrado
# 4          Area Natural de Manejo Integado Nacional
#
#                                           DESIG_ENG     DESIG_TYPE  \
# ...

# %%
south_america = americas.loc[americas['continent']=='South America']

# %%
ax = south_america.plot(figsize=(10,10), color='white', edgecolor='gray')
protected_areas.plot(ax=ax, alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
P_Area = sum(protected_areas['REP_AREA']-protected_areas['REP_M_AREA'])
totalArea = sum(south_america.geometry.to_crs(epsg=3035).area) / 10**6

# %%
ax = south_america.plot(figsize=(10,10), color='white', edgecolor='gray')
protected_areas[protected_areas['MARINE']!='2'].plot(ax=ax, alpha=0.4, zorder=1)
birds[birds.geometry.y < 0].plot(ax=ax, color='red', alpha=0.6, markersize=10, zorder=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Interactive Maps
